# %% [markdown]
# ##### 1 - Import Library

# %%
import pandas as pd 
import numpy as np
import os
import urllib
# %matplotlib inline

# %% [markdown]
# #### 2 - Load covid19 csv data

# %%
url="https://covid19.who.int/WHO-COVID-19-global-data.csv"
file_path=os.path.join("data","covid")

# %%
os.makedirs(file_path,exist_ok=True)
csv_path=os.path.join(file_path,'WHO-COVID-19-global-data.cs')
urllib.request.urlretrieve(url,csv_path)
# Out:
# ('data\\covid\\WHO-COVID-19-global-data.cs',
#  <http.client.HTTPMessage at 0x1a3fe47fee0>)

# %%
df = pd.read_csv(csv_path)

# %% [markdown]
# #### 3 - Explore Data

# %%
df
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 0         2020-01-03           AF  Afghanistan       EMRO          0
# 1         2020-01-04           AF  Afghanistan       EMRO          0
# 2         2020-01-05           AF  Afghanistan       EMRO          0
# 3         2020-01-06           AF  Afghanistan       EMRO          0
# 4         2020-01-07           AF  Afghanistan       EMRO          0
# ...              ...          ...          ...        ...        ...
# 132715    2021-07-11           ZW     Zimbabwe       AFRO       1787
# 132716    2021-07-12           ZW     Zimbabwe       AFRO        912
# 132717    2021-07-13           ZW     Zimbabwe       AFRO       2661
# 132718    2021-07-14           ZW     Zimbabwe       AFRO       2845
# 132719    2021-07-15           ZW     Zimbabwe       AFRO       3110
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 0                      0           0                  0
# ...

# %%
df_index = df.index
df_index
# Out:
# RangeIndex(start=0, stop=132720, step=1)

# %%
df_columns = df.columns
df_columns
# Out:
# Index(['Date_reported', 'Country_code', 'Country', 'WHO_region', 'New_cases',
#        'Cumulative_cases', 'New_deaths', 'Cumulative_deaths'],
#       dtype='object')

# %%
df_index.values
# Out:
# array([     0,      1,      2, ..., 132717, 132718, 132719], dtype=int64)

# %%
df.values
# Out:
# array([['2020-01-03', 'AF', 'Afghanistan', ..., 0, 0, 0],
#        ['2020-01-04', 'AF', 'Afghanistan', ..., 0, 0, 0],
#        ['2020-01-05', 'AF', 'Afghanistan', ..., 0, 0, 0],
#        ...,
#        ['2021-07-13', 'ZW', 'Zimbabwe', ..., 70426, 51, 2236],
#        ['2021-07-14', 'ZW', 'Zimbabwe', ..., 73271, 38, 2274],
#        ['2021-07-15', 'ZW', 'Zimbabwe', ..., 76381, 58, 2332]],
#       dtype=object)

# %%
df.dtypes
# Out:
# Date_reported        object
# Country_code         object
# Country              object
# WHO_region           object
# New_cases             int64
# Cumulative_cases      int64
# New_deaths            int64
# Cumulative_deaths     int64
# dtype: object

# %%
df.head()
# Out:
#   Date_reported Country_code      Country WHO_region  New_cases  \
# 0    2020-01-03           AF  Afghanistan       EMRO          0
# 1    2020-01-04           AF  Afghanistan       EMRO          0
# 2    2020-01-05           AF  Afghanistan       EMRO          0
# 3    2020-01-06           AF  Afghanistan       EMRO          0
# 4    2020-01-07           AF  Afghanistan       EMRO          0
#
#    Cumulative_cases  New_deaths  Cumulative_deaths
# 0                 0           0                  0
# 1                 0           0                  0
# 2                 0           0                  0
# 3                 0           0                  0
# 4                 0           0                  0

# %%
df.tail()
# Out:
#        Date_reported Country_code   Country WHO_region  New_cases  \
# 132715    2021-07-11           ZW  Zimbabwe       AFRO       1787
# 132716    2021-07-12           ZW  Zimbabwe       AFRO        912
# 132717    2021-07-13           ZW  Zimbabwe       AFRO       2661
# 132718    2021-07-14           ZW  Zimbabwe       AFRO       2845
# 132719    2021-07-15           ZW  Zimbabwe       AFRO       3110
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 132715             66853          42               2126
# 132716             67765          59               2185
# 132717             70426          51               2236
# 132718             73271          38               2274
# 132719             76381          58               2332

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132720 entries, 0 to 132719
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Date_reported      132720 non-null  object
#  1   Country_code       132160 non-null  object
#  2   Country            132720 non-null  object
#  3   WHO_region         132720 non-null  object
#  4   New_cases          132720 non-null  int64
#  5   Cumulative_cases   132720 non-null  int64
#  6   New_deaths         132720 non-null  int64
#  7   Cumulative_deaths  132720 non-null  int64
# dtypes: int64(4), object(4)
# memory usage: 8.1+ MB

# %%
df.describe()
# Out:
#            New_cases  Cumulative_cases     New_deaths  Cumulative_deaths
# count  132720.000000      1.327200e+05  132720.000000      132720.000000
# mean     1417.487583      2.597561e+05      30.585737        6220.486106
# std      9473.798641      1.612756e+06     170.363464       32443.478003
# min    -32952.000000      0.000000e+00     -60.000000           0.000000
# 25%         0.000000      2.300000e+01       0.000000           0.000000
# 50%         8.000000      2.844000e+03       0.000000          47.000000
# 75%       304.000000      5.477100e+04       4.000000         894.000000
# max    414188.000000      3.360482e+07    6508.000000      602820.000000

# %%
df['Country']
# Out:
# 0         Afghanistan
# 1         Afghanistan
# 2         Afghanistan
# 3         Afghanistan
# 4         Afghanistan
#              ...
# 132715       Zimbabwe
# 132716       Zimbabwe
# 132717       Zimbabwe
# 132718       Zimbabwe
# 132719       Zimbabwe
# Name: Country, Length: 132720, dtype: object

# %%
df['Country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Anguilla', 'Antigua and Barbuda', 'Argentina',
#        'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia (Plurinational State of)', 'Bonaire',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei Darussalam', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon',
#        'Canada', 'Cayman Islands', 'Central African Republic', 'Chad',
#        'Chile', 'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', 'Côte d’Ivoire', 'Croatia', 'Cuba', 'Curaçao',
#        'Cyprus', 'Czechia', "Democratic People's Republic of Korea",
#        'Democratic Republic of the Congo', 'Denmark', 'Djibouti',
# ...

# %%
df.columns = [col.strip() for  col in df.columns]
df.columns
# Out:
# Index(['Date_reported', 'Country_code', 'Country', 'WHO_region', 'New_cases',
#        'Cumulative_cases', 'New_deaths', 'Cumulative_deaths'],
#       dtype='object')

# %%
df.loc[1:4 , 'Country']
# Out:
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: Country, dtype: object

# %%
df.loc[1:8,['Country','New_cases']]
# Out:
#        Country  New_cases
# 1  Afghanistan          0
# 2  Afghanistan          0
# 3  Afghanistan          0
# 4  Afghanistan          0
# 5  Afghanistan          0
# 6  Afghanistan          0
# 7  Afghanistan          0
# 8  Afghanistan          0

# %%
df.Country == 'United States of America'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 132715    False
# 132716    False
# 132717    False
# 132718    False
# 132719    False
# Name: Country, Length: 132720, dtype: bool

# %%
df[df.Country == 'United States of America']
# Out:
#        Date_reported Country_code                   Country WHO_region  \
# 126560    2020-01-03           US  United States of America       AMRO
# 126561    2020-01-04           US  United States of America       AMRO
# 126562    2020-01-05           US  United States of America       AMRO
# 126563    2020-01-06           US  United States of America       AMRO
# 126564    2020-01-07           US  United States of America       AMRO
# ...              ...          ...                       ...        ...
# 127115    2021-07-11           US  United States of America       AMRO
# 127116    2021-07-12           US  United States of America       AMRO
# 127117    2021-07-13           US  United States of America       AMRO
# 127118    2021-07-14           US  United States of America       AMRO
# 127119    2021-07-15           US  United States of America       AMRO
#
#         New_cases  Cumulative_cases  New_deaths  Cumulative_deaths
# ...

# %%
df[df.New_deaths > 1000]
# Out:
#        Date_reported Country_code                           Country  \
# 4754      2020-10-03           AR                         Argentina
# 13689     2020-09-08           BO  Bolivia (Plurinational State of)
# 15819     2020-05-21           BR                            Brazil
# 15821     2020-05-23           BR                            Brazil
# 15822     2020-05-24           BR                            Brazil
# ...              ...          ...                               ...
# 127003    2021-03-21           US          United States of America
# 127008    2021-03-26           US          United States of America
# 127009    2021-03-27           US          United States of America
# 127010    2021-03-28           US          United States of America
# 127071    2021-05-28           US          United States of America
#
#        WHO_region  New_cases  Cumulative_cases  New_deaths  Cumulative_deaths
# ...

# %%
df.loc[df.New_deaths > 1000 ,['New_deaths','Country']]
# Out:
#         New_deaths                           Country
# 4754          3351                         Argentina
# 13689         1610  Bolivia (Plurinational State of)
# 15819         1179                            Brazil
# 15821         1188                            Brazil
# 15822         1001                            Brazil
# ...            ...                               ...
# 127003        1359          United States of America
# 127008        1091          United States of America
# 127009        1237          United States of America
# 127010        1170          United States of America
# 127071        1120          United States of America
#
# [658 rows x 2 columns]

# %%
df[(df.New_deaths > 1000) & (df.Country_code == 'US')]
# Out:
#        Date_reported Country_code                   Country WHO_region  \
# 126653    2020-04-05           US  United States of America       AMRO
# 126654    2020-04-06           US  United States of America       AMRO
# 126655    2020-04-07           US  United States of America       AMRO
# 126656    2020-04-08           US  United States of America       AMRO
# 126658    2020-04-10           US  United States of America       AMRO
# ...              ...          ...                       ...        ...
# 127003    2021-03-21           US  United States of America       AMRO
# 127008    2021-03-26           US  United States of America       AMRO
# 127009    2021-03-27           US  United States of America       AMRO
# 127010    2021-03-28           US  United States of America       AMRO
# 127071    2021-05-28           US  United States of America       AMRO
#
#         New_cases  Cumulative_cases  New_deaths  Cumulative_deaths
# ...

# %%
df.loc[df.Country_code == 'EG',['New_cases']].max()
# Out:
# New_cases    1774
# dtype: int64

# %%
df.loc[df.Country_code == 'EG',['New_cases']].min()
# Out:
# New_cases    0
# dtype: int64

# %%
df.loc[df.Country_code == 'EG',['New_cases']].sum()
# Out:
# New_cases    283409
# dtype: int64

# %%
df.loc[df.Country_code == 'EG',['New_deaths']].sum()
# Out:
# New_deaths    16418
# dtype: int64

# %%
df.loc[df.Country_code == 'EG',['Cumulative_deaths']].max()
# Out:
# Cumulative_deaths    16418
# dtype: int64
